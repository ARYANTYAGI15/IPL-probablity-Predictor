# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
matches_df = pd.read_csv(r"C:\Users\Dell\OneDrive\Desktop\Cuvette Assignments\IPL probablity predictor\matches.csv")
delevery_df = pd.read_csv(r"C:\Users\Dell\OneDrive\Desktop\Cuvette Assignments\IPL probablity predictor\deliveries.csv")

# %%
matches_df.head()
# Out:
#    id    Season       city        date                        team1  \
# 0   1  IPL-2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2  IPL-2017       Pune  06-04-2017               Mumbai Indians
# 2   3  IPL-2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4  IPL-2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5  IPL-2017  Bangalore  08-04-2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
delevery_df.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
players_df = pd.read_excel(r"C:\Users\Dell\OneDrive\Desktop\Cuvette Assignments\IPL probablity predictor\Players.xlsx")

# %%
players_df.head()
# Out:
#       Player_Name        DOB Batting_Hand         Bowling_Skill Country
# 0  A Ashish Reddy 1991-02-24   Right_Hand      Right-arm medium   India
# 1      A Chandila 1983-12-05   Right_Hand    Right-arm offbreak   India
# 2        A Chopra 1977-09-19   Right_Hand    Right-arm offbreak   India
# 3     A Choudhary        NaT   Right_hand  Left-arm fast-medium     NaN
# 4     A Dananjaya        NaT   Right_Hand    Right-arm offbreak     NaN

# %%
matches_df.shape
# Out:
# (756, 18)

# %%
delevery_df.shape
# Out:
# (179078, 21)

# %%
matches_df.columns
# Out:
# Index(['id', 'Season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
matches_df.drop(['umpire1', 'umpire2',
       'umpire3','toss_winner','toss_decision','player_of_match'],axis = 1,inplace =  True)

# %%
matches_df.shape
# Out:
# (756, 12)

# %%
delevery_df.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
delevery_df.drop(['bowler','is_super_over','dismissal_kind','fielder','wide_runs',
       'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs'],axis = 1,inplace= True)

# %%
delevery_df.shape
# Out:
# (179078, 12)

# %%
delevery_df.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker  batsman_runs  extra_runs  total_runs  \
# 0     1  DA Warner    S Dhawan             0           0           0
# 1     2  DA Warner    S Dhawan             0           0           0
# 2     3  DA Warner    S Dhawan             4           0           4
# 3     4  DA Warner    S Dhawan             0           0           0
# 4     5  DA Warner    S Dhawan             0           2           2
#
#   player_dismissed
# 0              NaN
# 1              NaN
# 2              NaN
# ...

# %%
total_score_df = (delevery_df.groupby(['match_id','inning']).sum()['total_runs'].reset_index())

# %%
total_score_df.head()
# Out:
#    match_id  inning  total_runs
# 0         1       1         207
# 1         1       2         172
# 2         2       1         184
# 3         2       2         187
# 4         3       1         183

# %%
total_score_df = total_score_df[total_score_df['inning']==1]

# %%
matches_df = matches_df.merge(total_score_df[['match_id','total_runs']],left_on='id',right_on='match_id')

# %%
matches_df.head()
# Out:
#    id    Season       city        date                        team1  \
# 0   1  IPL-2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2  IPL-2017       Pune  06-04-2017               Mumbai Indians
# 2   3  IPL-2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4  IPL-2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5  IPL-2017  Bangalore  08-04-2017  Royal Challengers Bangalore
#
#                          team2  result  dl_applied  \
# 0  Royal Challengers Bangalore  normal           0
# 1       Rising Pune Supergiant  normal           0
# 2        Kolkata Knight Riders  normal           0
# 3              Kings XI Punjab  normal           0
# 4             Delhi Daredevils  normal           0
#
#                         winner  win_by_runs  win_by_wickets  \
# 0          Sunrisers Hyderabad           35               0
# 1       Rising Pune Supergiant            0               7
# 2        Kolkata Knight Riders            0              10
# ...

# %%
teams = list(matches_df['team1'].unique())

# %%
teams
# Out:
# ['Sunrisers Hyderabad',
#  'Mumbai Indians',
#  'Gujarat Lions',
#  'Rising Pune Supergiant',
#  'Royal Challengers Bangalore',
#  'Kolkata Knight Riders',
#  'Delhi Daredevils',
#  'Kings XI Punjab',
#  'Chennai Super Kings',
#  'Rajasthan Royals',
#  'Deccan Chargers',
#  'Kochi Tuskers Kerala',
#  'Pune Warriors',
#  'Rising Pune Supergiants',
#  'Delhi Capitals']

# %%
teams = ['Sunrisers Hyderabad',
    'Mumbai Indians',
    'Gujarat Titans',
    'Royal Challengers Bangalore',
    'Kolkata Knight Riders',
    'Kings XI Punjab',
    'Chennai Super Kings',
    'Rajasthan Royals',
    'Delhi Capitals']

# %%
matches_df['team1'] = matches_df['team1'].str.replace('Delhi Daredevils', 'Delhi Capitals')
matches_df['team2'] = matches_df['team2'].str.replace('Delhi Daredevils', 'Delhi Capitals')

matches_df['team1'] = matches_df['team1'].str.replace('Deccan Chargers', 'Sunrisers Hyderabad')
matches_df['team2'] = matches_df['team2'].str.replace('Deccan Chargers', 'Sunrisers Hyderabad')

matches_df['team1'] = matches_df['team1'].str.replace('Gujarat Lions', 'Gujarat Titans')
matches_df['team2'] = matches_df['team2'].str.replace('Gujarat Lions', 'Gujarat Titans')

# %%
matches_df['team1'].unique()
# Out:
# array(['Sunrisers Hyderabad', 'Mumbai Indians', 'Gujarat Titans',
#        'Rising Pune Supergiant', 'Royal Challengers Bangalore',
#        'Kolkata Knight Riders', 'Delhi Capitals', 'Kings XI Punjab',
#        'Chennai Super Kings', 'Rajasthan Royals', 'Kochi Tuskers Kerala',
#        'Pune Warriors', 'Rising Pune Supergiants'], dtype=object)

# %%
matches_df = matches_df[matches_df['team1'].isin(teams)]
matches_df = matches_df[matches_df['team2'].isin(teams)]

# %%
matches_df.shape
# Out:
# (667, 14)

# %% [markdown]
# df applied --> 0 means normal ||| 1 means Duck word lewes applied

# %%
matches_df['dl_applied'].value_counts()
# Out:
# dl_applied
# 0    652
# 1     15
# Name: count, dtype: int64

# %%
matches_df = matches_df[matches_df['dl_applied'] == 0]

# %%
matches_df.head()
# Out:
#    id    Season       city        date                        team1  \
# 0   1  IPL-2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 2   3  IPL-2017     Rajkot  07-04-2017               Gujarat Titans
# 4   5  IPL-2017  Bangalore  08-04-2017  Royal Challengers Bangalore
# 5   6  IPL-2017  Hyderabad  09-04-2017               Gujarat Titans
# 6   7  IPL-2017     Mumbai  09-04-2017        Kolkata Knight Riders
#
#                          team2  result  dl_applied  \
# 0  Royal Challengers Bangalore  normal           0
# 2        Kolkata Knight Riders  normal           0
# 4               Delhi Capitals  normal           0
# 5          Sunrisers Hyderabad  normal           0
# 6               Mumbai Indians  normal           0
#
#                         winner  win_by_runs  win_by_wickets  \
# 0          Sunrisers Hyderabad           35               0
# 2        Kolkata Knight Riders            0              10
# 4  Royal Challengers Bangalore           15               0
# ...

# %%
matches_df = matches_df[['match_id','city','winner','total_runs']]

# %%
matches_df.head()
# Out:
#    match_id       city                       winner  total_runs
# 0         1  Hyderabad          Sunrisers Hyderabad         207
# 2         3     Rajkot        Kolkata Knight Riders         183
# 4         5  Bangalore  Royal Challengers Bangalore         157
# 5         6  Hyderabad          Sunrisers Hyderabad         135
# 6         7     Mumbai               Mumbai Indians         178

# %%
delevery_df.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker  batsman_runs  extra_runs  total_runs  \
# 0     1  DA Warner    S Dhawan             0           0           0
# 1     2  DA Warner    S Dhawan             0           0           0
# 2     3  DA Warner    S Dhawan             4           0           4
# 3     4  DA Warner    S Dhawan             0           0           0
# 4     5  DA Warner    S Dhawan             0           2           2
#
#   player_dismissed
# 0              NaN
# 1              NaN
# 2              NaN
# ...

# %%
delevery_df = delevery_df[delevery_df['inning'] == 2]

# %%
delevery_df.head()
# Out:
#      match_id  inning                 batting_team         bowling_team  over  \
# 125         1       2  Royal Challengers Bangalore  Sunrisers Hyderabad     1
# 126         1       2  Royal Challengers Bangalore  Sunrisers Hyderabad     1
# 127         1       2  Royal Challengers Bangalore  Sunrisers Hyderabad     1
# 128         1       2  Royal Challengers Bangalore  Sunrisers Hyderabad     1
# 129         1       2  Royal Challengers Bangalore  Sunrisers Hyderabad     1
#
#      ball        batsman    non_striker  batsman_runs  extra_runs  total_runs  \
# 125     1       CH Gayle  Mandeep Singh             1           0           1
# 126     2  Mandeep Singh       CH Gayle             0           0           0
# 127     3  Mandeep Singh       CH Gayle             0           0           0
# 128     4  Mandeep Singh       CH Gayle             2           0           2
# 129     5  Mandeep Singh       CH Gayle             4           0           4
#
#     player_dismissed
# ...

# %%
delevery_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 86240 entries, 125 to 179077
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   match_id          86240 non-null  int64
#  1   inning            86240 non-null  int64
#  2   batting_team      86240 non-null  object
#  3   bowling_team      86240 non-null  object
#  4   over              86240 non-null  int64
#  5   ball              86240 non-null  int64
#  6   batsman           86240 non-null  object
#  7   non_striker       86240 non-null  object
#  8   batsman_runs      86240 non-null  int64
#  9   extra_runs        86240 non-null  int64
#  10  total_runs        86240 non-null  int64
#  11  player_dismissed  4216 non-null   object
# dtypes: int64(7), object(5)
# memory usage: 8.6+ MB

# %%
delevery_df = matches_df.merge(delevery_df,on = 'match_id')

# %%
delevery_df.head()
# Out:
#    match_id       city               winner  total_runs_x  inning  \
# 0         1  Hyderabad  Sunrisers Hyderabad           207       2
# 1         1  Hyderabad  Sunrisers Hyderabad           207       2
# 2         1  Hyderabad  Sunrisers Hyderabad           207       2
# 3         1  Hyderabad  Sunrisers Hyderabad           207       2
# 4         1  Hyderabad  Sunrisers Hyderabad           207       2
#
#                   batting_team         bowling_team  over  ball  \
# 0  Royal Challengers Bangalore  Sunrisers Hyderabad     1     1
# 1  Royal Challengers Bangalore  Sunrisers Hyderabad     1     2
# 2  Royal Challengers Bangalore  Sunrisers Hyderabad     1     3
# 3  Royal Challengers Bangalore  Sunrisers Hyderabad     1     4
# 4  Royal Challengers Bangalore  Sunrisers Hyderabad     1     5
#
#          batsman    non_striker  batsman_runs  extra_runs  total_runs_y  \
# 0       CH Gayle  Mandeep Singh             1           0             1
# ...

# %%
delevery_df.columns
# Out:
# Index(['match_id', 'city', 'winner', 'total_runs_x', 'inning', 'batting_team',
#        'bowling_team', 'over', 'ball', 'batsman', 'non_striker',
#        'batsman_runs', 'extra_runs', 'total_runs_y', 'player_dismissed'],
#       dtype='object')

# %%
delevery_df.rename(columns={'total_runs_x':'total_runs','total_runs_y':'Ball_score'},inplace=True)

# %%
delevery_df.head()
# Out:
#    match_id       city               winner  total_runs  inning  \
# 0         1  Hyderabad  Sunrisers Hyderabad         207       2
# 1         1  Hyderabad  Sunrisers Hyderabad         207       2
# 2         1  Hyderabad  Sunrisers Hyderabad         207       2
# 3         1  Hyderabad  Sunrisers Hyderabad         207       2
# 4         1  Hyderabad  Sunrisers Hyderabad         207       2
#
#                   batting_team         bowling_team  over  ball  \
# 0  Royal Challengers Bangalore  Sunrisers Hyderabad     1     1
# 1  Royal Challengers Bangalore  Sunrisers Hyderabad     1     2
# 2  Royal Challengers Bangalore  Sunrisers Hyderabad     1     3
# 3  Royal Challengers Bangalore  Sunrisers Hyderabad     1     4
# 4  Royal Challengers Bangalore  Sunrisers Hyderabad     1     5
#
#          batsman    non_striker  batsman_runs  extra_runs  Ball_score  \
# 0       CH Gayle  Mandeep Singh             1           0           1
# ...

# %%
delevery_df['score'] = delevery_df[['match_id','Ball_score']].groupby('match_id').cumsum()['Ball_score']

# %%
delevery_df
# Out:
#        match_id       city               winner  total_runs  inning  \
# 0             1  Hyderabad  Sunrisers Hyderabad         207       2
# 1             1  Hyderabad  Sunrisers Hyderabad         207       2
# 2             1  Hyderabad  Sunrisers Hyderabad         207       2
# 3             1  Hyderabad  Sunrisers Hyderabad         207       2
# 4             1  Hyderabad  Sunrisers Hyderabad         207       2
# ...         ...        ...                  ...         ...     ...
# 75335     11415  Hyderabad       Mumbai Indians         152       2
# 75336     11415  Hyderabad       Mumbai Indians         152       2
# 75337     11415  Hyderabad       Mumbai Indians         152       2
# 75338     11415  Hyderabad       Mumbai Indians         152       2
# 75339     11415  Hyderabad       Mumbai Indians         152       2
#
#                       batting_team         bowling_team  over  ball  \
# 0      Royal Challengers Bangalore  Sunrisers Hyderabad     1     1
# ...

# %%
delevery_df['target_score'] = (delevery_df['total_runs']+1) - delevery_df['score']

# %%
delevery_df
# Out:
#        match_id       city               winner  total_runs  inning  \
# 0             1  Hyderabad  Sunrisers Hyderabad         207       2
# 1             1  Hyderabad  Sunrisers Hyderabad         207       2
# 2             1  Hyderabad  Sunrisers Hyderabad         207       2
# 3             1  Hyderabad  Sunrisers Hyderabad         207       2
# 4             1  Hyderabad  Sunrisers Hyderabad         207       2
# ...         ...        ...                  ...         ...     ...
# 75335     11415  Hyderabad       Mumbai Indians         152       2
# 75336     11415  Hyderabad       Mumbai Indians         152       2
# 75337     11415  Hyderabad       Mumbai Indians         152       2
# 75338     11415  Hyderabad       Mumbai Indians         152       2
# 75339     11415  Hyderabad       Mumbai Indians         152       2
#
#                       batting_team         bowling_team  over  ball  \
# 0      Royal Challengers Bangalore  Sunrisers Hyderabad     1     1
# ...

# %%
delevery_df['remaining_balls'] = (120 - ((delevery_df['over']-1)*6 + delevery_df['ball']))

# %%
delevery_df
# Out:
#        match_id       city               winner  total_runs  inning  \
# 0             1  Hyderabad  Sunrisers Hyderabad         207       2
# 1             1  Hyderabad  Sunrisers Hyderabad         207       2
# 2             1  Hyderabad  Sunrisers Hyderabad         207       2
# 3             1  Hyderabad  Sunrisers Hyderabad         207       2
# 4             1  Hyderabad  Sunrisers Hyderabad         207       2
# ...         ...        ...                  ...         ...     ...
# 75335     11415  Hyderabad       Mumbai Indians         152       2
# 75336     11415  Hyderabad       Mumbai Indians         152       2
# 75337     11415  Hyderabad       Mumbai Indians         152       2
# 75338     11415  Hyderabad       Mumbai Indians         152       2
# 75339     11415  Hyderabad       Mumbai Indians         152       2
#
#                       batting_team         bowling_team  over  ball  \
# 0      Royal Challengers Bangalore  Sunrisers Hyderabad     1     1
# ...

# %%
delevery_df['player_dismissed'] = delevery_df['player_dismissed'].fillna(0)

# %%
delevery_df
# Out:
#        match_id       city               winner  total_runs  inning  \
# 0             1  Hyderabad  Sunrisers Hyderabad         207       2
# 1             1  Hyderabad  Sunrisers Hyderabad         207       2
# 2             1  Hyderabad  Sunrisers Hyderabad         207       2
# 3             1  Hyderabad  Sunrisers Hyderabad         207       2
# 4             1  Hyderabad  Sunrisers Hyderabad         207       2
# ...         ...        ...                  ...         ...     ...
# 75335     11415  Hyderabad       Mumbai Indians         152       2
# 75336     11415  Hyderabad       Mumbai Indians         152       2
# 75337     11415  Hyderabad       Mumbai Indians         152       2
# 75338     11415  Hyderabad       Mumbai Indians         152       2
# 75339     11415  Hyderabad       Mumbai Indians         152       2
#
#                       batting_team         bowling_team  over  ball  \
# 0      Royal Challengers Bangalore  Sunrisers Hyderabad     1     1
# ...

# %%
delevery_df['player_dismissed'] = delevery_df['player_dismissed'].apply(lambda x:x if x == 0 else 1).astype('int64')

# %%
delevery_df
# Out:
#        match_id       city               winner  total_runs  inning  \
# 0             1  Hyderabad  Sunrisers Hyderabad         207       2
# 1             1  Hyderabad  Sunrisers Hyderabad         207       2
# 2             1  Hyderabad  Sunrisers Hyderabad         207       2
# 3             1  Hyderabad  Sunrisers Hyderabad         207       2
# 4             1  Hyderabad  Sunrisers Hyderabad         207       2
# ...         ...        ...                  ...         ...     ...
# 75335     11415  Hyderabad       Mumbai Indians         152       2
# 75336     11415  Hyderabad       Mumbai Indians         152       2
# 75337     11415  Hyderabad       Mumbai Indians         152       2
# 75338     11415  Hyderabad       Mumbai Indians         152       2
# 75339     11415  Hyderabad       Mumbai Indians         152       2
#
#                       batting_team         bowling_team  over  ball  \
# 0      Royal Challengers Bangalore  Sunrisers Hyderabad     1     1
# ...

# %%
delevery_df['wickets'] = delevery_df[['match_id' , 'player_dismissed']].groupby('match_id').cumsum()['player_dismissed'].values

# %%
delevery_df
# Out:
#        match_id       city               winner  total_runs  inning  \
# 0             1  Hyderabad  Sunrisers Hyderabad         207       2
# 1             1  Hyderabad  Sunrisers Hyderabad         207       2
# 2             1  Hyderabad  Sunrisers Hyderabad         207       2
# 3             1  Hyderabad  Sunrisers Hyderabad         207       2
# 4             1  Hyderabad  Sunrisers Hyderabad         207       2
# ...         ...        ...                  ...         ...     ...
# 75335     11415  Hyderabad       Mumbai Indians         152       2
# 75336     11415  Hyderabad       Mumbai Indians         152       2
# 75337     11415  Hyderabad       Mumbai Indians         152       2
# 75338     11415  Hyderabad       Mumbai Indians         152       2
# 75339     11415  Hyderabad       Mumbai Indians         152       2
#
#                       batting_team         bowling_team  over  ball  \
# 0      Royal Challengers Bangalore  Sunrisers Hyderabad     1     1
# ...

# %%
delevery_df['wickets'] =10 -  delevery_df['wickets']

# %%
delevery_df
# Out:
#        match_id       city               winner  total_runs  inning  \
# 0             1  Hyderabad  Sunrisers Hyderabad         207       2
# 1             1  Hyderabad  Sunrisers Hyderabad         207       2
# 2             1  Hyderabad  Sunrisers Hyderabad         207       2
# 3             1  Hyderabad  Sunrisers Hyderabad         207       2
# 4             1  Hyderabad  Sunrisers Hyderabad         207       2
# ...         ...        ...                  ...         ...     ...
# 75335     11415  Hyderabad       Mumbai Indians         152       2
# 75336     11415  Hyderabad       Mumbai Indians         152       2
# 75337     11415  Hyderabad       Mumbai Indians         152       2
# 75338     11415  Hyderabad       Mumbai Indians         152       2
# 75339     11415  Hyderabad       Mumbai Indians         152       2
#
#                       batting_team         bowling_team  over  ball  \
# 0      Royal Challengers Bangalore  Sunrisers Hyderabad     1     1
# ...

# %%
delevery_df['crr'] = (delevery_df['score'])*6/(120 - delevery_df['remaining_balls'])

# %%
delevery_df
# Out:
#        match_id       city               winner  total_runs  inning  \
# 0             1  Hyderabad  Sunrisers Hyderabad         207       2
# 1             1  Hyderabad  Sunrisers Hyderabad         207       2
# 2             1  Hyderabad  Sunrisers Hyderabad         207       2
# 3             1  Hyderabad  Sunrisers Hyderabad         207       2
# 4             1  Hyderabad  Sunrisers Hyderabad         207       2
# ...         ...        ...                  ...         ...     ...
# 75335     11415  Hyderabad       Mumbai Indians         152       2
# 75336     11415  Hyderabad       Mumbai Indians         152       2
# 75337     11415  Hyderabad       Mumbai Indians         152       2
# 75338     11415  Hyderabad       Mumbai Indians         152       2
# 75339     11415  Hyderabad       Mumbai Indians         152       2
#
#                       batting_team         bowling_team  over  ball  \
# 0      Royal Challengers Bangalore  Sunrisers Hyderabad     1     1
# ...

# %%
delevery_df['rrr'] = (delevery_df['target_score'])*6/(delevery_df['remaining_balls'])

# %%
delevery_df
# Out:
#        match_id       city               winner  total_runs  inning  \
# 0             1  Hyderabad  Sunrisers Hyderabad         207       2
# 1             1  Hyderabad  Sunrisers Hyderabad         207       2
# 2             1  Hyderabad  Sunrisers Hyderabad         207       2
# 3             1  Hyderabad  Sunrisers Hyderabad         207       2
# 4             1  Hyderabad  Sunrisers Hyderabad         207       2
# ...         ...        ...                  ...         ...     ...
# 75335     11415  Hyderabad       Mumbai Indians         152       2
# 75336     11415  Hyderabad       Mumbai Indians         152       2
# 75337     11415  Hyderabad       Mumbai Indians         152       2
# 75338     11415  Hyderabad       Mumbai Indians         152       2
# 75339     11415  Hyderabad       Mumbai Indians         152       2
#
#                       batting_team         bowling_team  over  ball  \
# 0      Royal Challengers Bangalore  Sunrisers Hyderabad     1     1
# ...

# %%
def result(row):
    if row['batting_team'] == row['winner']:
        return 1
    else:
        return 0

# %%
delevery_df['result'] = delevery_df.apply(result,axis=1)

# %%
delevery_df
# Out:
#        match_id       city               winner  total_runs  inning  \
# 0             1  Hyderabad  Sunrisers Hyderabad         207       2
# 1             1  Hyderabad  Sunrisers Hyderabad         207       2
# 2             1  Hyderabad  Sunrisers Hyderabad         207       2
# 3             1  Hyderabad  Sunrisers Hyderabad         207       2
# 4             1  Hyderabad  Sunrisers Hyderabad         207       2
# ...         ...        ...                  ...         ...     ...
# 75335     11415  Hyderabad       Mumbai Indians         152       2
# 75336     11415  Hyderabad       Mumbai Indians         152       2
# 75337     11415  Hyderabad       Mumbai Indians         152       2
# 75338     11415  Hyderabad       Mumbai Indians         152       2
# 75339     11415  Hyderabad       Mumbai Indians         152       2
#
#                       batting_team         bowling_team  over  ball  \
# 0      Royal Challengers Bangalore  Sunrisers Hyderabad     1     1
# ...

# %%
delevery_df.columns
# Out:
# Index(['match_id', 'city', 'winner', 'total_runs', 'inning', 'batting_team',
#        'bowling_team', 'over', 'ball', 'batsman', 'non_striker',
#        'batsman_runs', 'extra_runs', 'Ball_score', 'player_dismissed', 'score',
#        'target_score', 'remaining_balls', 'wickets', 'crr', 'rrr', 'result'],
#       dtype='object')

# %%
Model_df = delevery_df[['batting_team','bowling_team','city','score','wickets','remaining_balls','target_score','crr','rrr','result']]

# %%
Model_df
# Out:
#                       batting_team         bowling_team       city  score  \
# 0      Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad      1
# 1      Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad      1
# 2      Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad      1
# 3      Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad      3
# 4      Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad      7
# ...                            ...                  ...        ...    ...
# 75335          Chennai Super Kings       Mumbai Indians  Hyderabad    152
# 75336          Chennai Super Kings       Mumbai Indians  Hyderabad    154
# 75337          Chennai Super Kings       Mumbai Indians  Hyderabad    155
# 75338          Chennai Super Kings       Mumbai Indians  Hyderabad    157
# 75339          Chennai Super Kings       Mumbai Indians  Hyderabad    157
#
#        wickets  remaining_balls  target_score       crr        rrr  result
# ...

# %%
Model_df.isnull().sum()
# Out:
# batting_team         0
# bowling_team         0
# city               832
# score                0
# wickets              0
# remaining_balls      0
# target_score         0
# crr                  0
# rrr                  5
# result               0
# dtype: int64

# %%
Model_df[Model_df['city'].isna()]
# Out:
#                       batting_team         bowling_team city  score  wickets  \
# 43674  Royal Challengers Bangalore       Mumbai Indians  NaN      0       10
# 43675  Royal Challengers Bangalore       Mumbai Indians  NaN      4       10
# 43676  Royal Challengers Bangalore       Mumbai Indians  NaN      5       10
# 43677  Royal Challengers Bangalore       Mumbai Indians  NaN      7       10
# 43678  Royal Challengers Bangalore       Mumbai Indians  NaN      7       10
# ...                            ...                  ...  ...    ...      ...
# 45510               Mumbai Indians  Sunrisers Hyderabad  NaN    154        3
# 45511               Mumbai Indians  Sunrisers Hyderabad  NaN    154        3
# 45512               Mumbai Indians  Sunrisers Hyderabad  NaN    155        3
# 45513               Mumbai Indians  Sunrisers Hyderabad  NaN    156        3
# 45514               Mumbai Indians  Sunrisers Hyderabad  NaN    157        3
#
# ...

# %%
Model_df.dropna(inplace=True)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_23596\2202708226.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Model_df.dropna(inplace=True)

# %%
Model_df.isnull().sum()
# Out:
# batting_team       0
# bowling_team       0
# city               0
# score              0
# wickets            0
# remaining_balls    0
# target_score       0
# crr                0
# rrr                0
# result             0
# dtype: int64

# %%
Model_df.describe()
# Out:
# c:\Users\Dell\OneDrive\Desktop\Cuvette Assignments\IPL probablity predictor\IPL\Lib\site-packages\numpy\_core\_methods.py:51: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#               score       wickets  remaining_balls  target_score  \
# count  74503.000000  74503.000000     74503.000000  74503.000000
# mean      73.593641      7.539951        62.744252     93.300109
# std       47.021034      2.137884        33.365914     50.199133
# min        0.000000      0.000000        -2.000000    -15.000000
# 25%       34.000000      6.000000        35.000000     54.000000
# 50%       70.000000      8.000000        63.000000     93.000000
# 75%      109.000000      9.000000        92.000000    131.000000
# max      223.000000     10.000000       119.000000    250.000000
#
#                 crr           rrr        result
# count  74503.000000  7.450300e+04  74503.000000
# ...

# %%
Model_df = Model_df[Model_df['remaining_balls'] != 0]

# %%
Model_df.describe()
# Out:
#               score       wickets  remaining_balls  target_score  \
# count  74262.000000  74262.000000     74262.000000  74262.000000
# mean      73.318103      7.555129        62.947874     93.536088
# std       46.827172      2.122778        33.227690     50.098611
# min        0.000000      0.000000        -2.000000    -15.000000
# 25%       34.000000      6.000000        35.000000     54.000000
# 50%       70.000000      8.000000        64.000000     93.000000
# 75%      108.000000      9.000000        92.000000    131.000000
# max      222.000000     10.000000       119.000000    250.000000
#
#                 crr           rrr        result
# count  74262.000000  74262.000000  74262.000000
# mean       7.482496     10.515160      0.537045
# std        2.289951     13.860596      0.498629
# min        0.000000   -516.000000      0.000000
# 25%        6.285714      7.230769      0.000000
# 50%        7.500000      8.953846      1.000000
# ...

# %%
Model_df = Model_df.sample(Model_df.shape[0])

# %%
Model_df.sample()
# Out:
#            batting_team    bowling_team    city  score  wickets  \
# 63799  Rajasthan Royals  Mumbai Indians  Jaipur     53        8
#
#        remaining_balls  target_score       crr       rrr  result
# 63799               79           120  7.756098  9.113924       1

# %%
X = Model_df.iloc[:,:-1]

Y = Model_df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.2,random_state=2)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

# %%
trf = ColumnTransformer([
    ('trf', OneHotEncoder(sparse_output=False, drop='first'), ['batting_team', 'bowling_team', 'city'])
], remainder='passthrough')

# %%
trf
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('trf',
#                                  OneHotEncoder(drop='first',
#                                                sparse_output=False),
#                                  ['batting_team', 'bowling_team', 'city'])])

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline

# %%
pipe = Pipeline(steps=[
    ('step1',trf),
    ('step2',LogisticRegression(solver='liblinear'))
])

# %%
pipe.fit(X_train,Y_train)
# Out:
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('trf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse_output=False),
#                                                   ['batting_team',
#                                                    'bowling_team', 'city'])])),
#                 ('step2', LogisticRegression(solver='liblinear'))])

# %%
Y_prediction = pipe.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(Y_test,Y_prediction)
# Out:
# 0.8091967952602168

# %%
import pickle as pkl

# %%
pkl.dump(pipe,open('model.pkl','wb'))

# %%
pkl.dump(teams,open('team.pkl','wb'))

# %%
cities = list(Model_df['city'].unique())

# %%
pkl.dump(cities,open('city.pkl','wb'))
